# %% [markdown]
# <a id='Exploratory Data Analysis'></a>
#
# ## <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">  Exploratory Data Analysis

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.1 Load the libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.2. Import the dataset (HH_Provider_Apr2025.csv):

# %%
data =  pd.read_csv('../data/HH_Provider_Apr2025.csv') # Import the dataset named 'HH_Provider_Apr2025.csv'
data.head()  # view the first 5 rows of the data
# Out:
#   State  CMS Certification Number (CCN)                    Provider Name  \
# 0    AK                           27001    PROVIDENCE HOME HEALTH ALASKA
# 1    AK                           27002    HOSPICE & HOME CARE OF JUNEAU
# 2    AK                           27006  FAIRBANKS MEMORIAL HOSPITAL HHA
# 3    AK                           27008     ANCORA HOME HEALTH & HOSPICE
# 4    AK                           27009   PETERSBURG MEDICAL CENTER HOME
#
#                        Address   City/Town  ZIP Code Telephone Number  \
# 0  4001 DALE STREET, SUITE 101   ANCHORAGE     99508       9075630130
# 1         1803 GLACIER HIGHWAY      JUNEAU     99801       9074633113
# 2              1701 GILLAM WAY   FAIRBANKS     99701       9074585410
# 3     3831 E BLUE LUPINE DRIVE     WASILLA     99654       9075610700
# 4                 P.O. BOX 589  PETERSBURG     99833       9077724291
#
#      Type of Ownership Offers Nursing Care Services  \
# 0           NON-PROFIT                          Yes
# 1           NON-PROFIT                          Yes
# 2           NON-PROFIT                          Yes
# 3          PROPRIETARY                          Yes
# 4  GOVERNMENT OPERATED                          Yes
#
#   Offers Physical Therapy Services  ... PPH Denominator PPH Observed Rate  \
# 0                              Yes  ...             455             10.11
# 1                              Yes  ...               -                 -
# 2                              Yes  ...             134              5.97
# 3                              Yes  ...             949              6.32
# 4                              Yes  ...              62              8.06
#
#   PPH Risk-Standardized Rate PPH Risk-Standardized Rate (Lower Limit)  \
# 0                       8.37                                     6.56
# 1                          -                                        -
# 2                       7.43                                     4.41
# 3                       6.85                                     5.42
# 4                      11.06                                     6.71
#
#   PPH Risk-Standardized Rate (Upper Limit) PPH Performance Categorization  \
# 0                                    10.49          Same As National Rate
# 1                                        -                              -
# 2                                    11.42          Same As National Rate
# 3                                     8.59      Better Than National Rate
# 4                                    18.52          Same As National Rate
#
#              Footnote for PPH Risk-Standardized Rate  \
# 0                                                  -
# 1  This measure currently does not have data or p...
# 2                                                  -
# 3                                                  -
# 4                                                  -
#
#   How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally  \
# 0                                               0.96
# 1                                               0.71
# 2                                               0.77
# 3                                               0.85
# 4                                               1.09
#
#   Footnote for how much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally  \
# 0                                                  -
# 1                                                  -
# 2                                                  -
# 3                                                  -
# 4                                                  -
#
#   No. of episodes to calc how much Medicare spends per episode of care at agency, compared to spending at all agencies (national)
# 0                                              1,345
# 1                                                151
# 2                                                439
# 3                                              2,406
# 4                                                232
#
# [5 rows x 96 columns]

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.3 Check the dimension of the data.

# %%
data.shape # see the shape of the data
# Out:
# (12069, 96)

# %% [markdown]
# **There are 12069 Observations / Rows and 96 Attributes / Columns.**

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.4 Check the Information about the data and the datatypes of each respective attributes.

# %%
data.info() # To see the data type of each of the variable, number of values entered in each of the variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12069 entries, 0 to 12068
# Data columns (total 96 columns):
#  #   Column                                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                                    --------------  -----
#  0   State                                                                                                                                     12069 non-null  object
#  1   CMS Certification Number (CCN)                                                                                                            12069 non-null  int64
#  2   Provider Name                                                                                                                             12069 non-null  object
#  3   Address                                                                                                                                   12069 non-null  object
#  4   City/Town                                                                                                                                 12069 non-null  object
#  5   ZIP Code                                                                                                                                  12069 non-null  int64
#  6   Telephone Number                                                                                                                          12069 non-null  object
#  7   Type of Ownership                                                                                                                         12069 non-null  object
#  8   Offers Nursing Care Services                                                                                                              12069 non-null  object
#  9   Offers Physical Therapy Services                                                                                                          12069 non-null  object
#  10  Offers Occupational Therapy Services                                                                                                      12069 non-null  object
#  11  Offers Speech Pathology Services                                                                                                          12069 non-null  object
#  12  Offers Medical Social Services                                                                                                            12069 non-null  object
#  13  Offers Home Health Aide Services                                                                                                          12069 non-null  object
#  14  Certification Date                                                                                                                        12069 non-null  object
#  15  Quality of patient care star rating                                                                                                       12069 non-null  object
#  16  Footnote for quality of patient care star rating                                                                                          12069 non-null  object
#  17  Numerator for how often the home health team began their patients' care in a timely manner                                                12069 non-null  object
#  18  Denominator for how often the home health team began their patients' care in a timely manner                                              12069 non-null  object
#  19  How often the home health team began their patients' care in a timely manner                                                              12069 non-null  object
#  20  Footnote for how often the home health team began their patients' care in a timely manner                                                 12069 non-null  object
#  21  Numerator for how often the home health team determined whether patients received a flu shot for the current flu season                   12069 non-null  object
#  22  Denominator for how often the home health team determined whether patients received a flu shot for the current flu season                 12069 non-null  object
#  23  How often the home health team determined whether patients received a flu shot for the current flu season                                 12069 non-null  object
#  24  Footnote for how often the home health team determined whether patients received a flu shot for the current flu season                    12069 non-null  object
#  25  Numerator for how often patients got better at walking or moving around                                                                   12069 non-null  object
#  26  Denominator for how often patients got better at walking or moving around                                                                 12069 non-null  object
#  27  How often patients got better at walking or moving around                                                                                 12069 non-null  object
#  28  Footnote for how often patients got better at walking or moving around                                                                    12069 non-null  object
#  29  Numerator for how often patients got better at getting in and out of bed                                                                  12069 non-null  object
#  30  Denominator for how often patients got better at getting in and out of bed                                                                12069 non-null  object
#  31  How often patients got better at getting in and out of bed                                                                                12069 non-null  object
#  32  Footnote for how often patients got better at getting in and out of bed                                                                   12069 non-null  object
#  33  Numerator for how often patients got better at bathing                                                                                    12069 non-null  object
#  34  Denominator for how often patients got better at bathing                                                                                  12069 non-null  object
#  35  How often patients got better at bathing                                                                                                  12069 non-null  object
#  36  Footnote for how often patients got better at bathing                                                                                     12069 non-null  object
#  37  Numerator for how often patients' breathing improved                                                                                      12069 non-null  object
#  38  Denominator for how often patients' breathing improved                                                                                    12069 non-null  object
#  39  How often patients' breathing improved                                                                                                    12069 non-null  object
#  40  Footnote for how often patients' breathing improved                                                                                       12069 non-null  object
#  41  Numerator for how often patients got better at taking their drugs correctly by mouth                                                      12069 non-null  object
#  42  Denominator for how often patients got better at taking their drugs correctly by mouth                                                    12069 non-null  object
#  43  How often patients got better at taking their drugs correctly by mouth                                                                    12069 non-null  object
#  44  Footnote for how often patients got better at taking their drugs correctly by mouth                                                       12069 non-null  object
#  45  Numerator for Changes in skin integrity post-acute care: pressure ulcer/injury                                                            12069 non-null  object
#  46  Denominator for Changes in skin integrity post-acute care: pressure ulcer/injury                                                          12069 non-null  object
#  47  Changes in skin integrity post-acute care: pressure ulcer/injury                                                                          12069 non-null  object
#  48  Footnote Changes in skin integrity post-acute care: pressure ulcer/injury                                                                 12069 non-null  object
#  49  Numerator for how often physician-recommended actions to address medication issues were completely timely                                 12069 non-null  object
#  50  Denominator for how often physician-recommended actions to address medication issues were completely timely                               12069 non-null  object
#  51  How often physician-recommended actions to address medication issues were completely timely                                               12069 non-null  object
#  52  Footnote for how often physician-recommended actions to address medication issues were completely timely                                  12069 non-null  object
#  53  Numerator for Percent of Residents Experiencing One or More Falls with Major Injury                                                       12069 non-null  object
#  54  Denominator for Percent of Residents Experiencing One or More Falls with Major Injury                                                     12069 non-null  object
#  55  Percent of Residents Experiencing One or More Falls with Major Injury                                                                     12069 non-null  object
#  56  Footnote for Percent of Residents Experiencing One or More Falls with Major Injury                                                        12069 non-null  object
#  57  Numerator for Discharge Function Score                                                                                                    12069 non-null  object
#  58  Denominator for Discharge Function Score                                                                                                  12069 non-null  object
#  59  Discharge Function Score                                                                                                                  12069 non-null  object
#  60  Footnote for Discharge Function Score                                                                                                     12069 non-null  object
#  61  Numerator for Transfer of Health Information to the Provider                                                                              12069 non-null  object
#  62  Denominator for Transfer of Health Information to the Provider                                                                            12069 non-null  object
#  63  Transfer of Health Information to the Provider                                                                                            12069 non-null  object
#  64  Footnote for Transfer of Health Information to the Provider                                                                               12069 non-null  object
#  65  Numerator for Transfer of Health Information to the Patient                                                                               12069 non-null  object
#  66  Denominator for Transfer of Health Information to the Patient                                                                             12069 non-null  object
#  67  Transfer of Health Information to the Patient                                                                                             12069 non-null  object
#  68  Footnote for Transfer of Health Information to the Patient                                                                                12069 non-null  object
#  69  DTC Numerator                                                                                                                             12069 non-null  object
#  70  DTC Denominator                                                                                                                           12069 non-null  object
#  71  DTC Observed Rate                                                                                                                         12069 non-null  object
#  72  DTC Risk-Standardized Rate                                                                                                                12069 non-null  object
#  73  DTC Risk-Standardized Rate (Lower Limit)                                                                                                  12069 non-null  object
#  74  DTC Risk-Standardized Rate (Upper Limit)                                                                                                  12069 non-null  object
#  75  DTC Performance Categorization                                                                                                            12069 non-null  object
#  76  Footnote for DTC Risk-Standardized Rate                                                                                                   12069 non-null  object
#  77  PPR Numerator                                                                                                                             12069 non-null  object
#  78  PPR Denominator                                                                                                                           12069 non-null  object
#  79  PPR Observed Rate                                                                                                                         12069 non-null  object
#  80  PPR Risk-Standardized Rate                                                                                                                12069 non-null  object
#  81  PPR Risk-Standardized Rate (Lower Limit)                                                                                                  12069 non-null  object
#  82  PPR Risk-Standardized Rate (Upper Limit)                                                                                                  12069 non-null  object
#  83  PPR Performance Categorization                                                                                                            12069 non-null  object
#  84  Footnote for PPR Risk-Standardized Rate                                                                                                   12069 non-null  object
#  85  PPH Numerator                                                                                                                             12069 non-null  object
#  86  PPH Denominator                                                                                                                           12069 non-null  object
#  87  PPH Observed Rate                                                                                                                         12069 non-null  object
#  88  PPH Risk-Standardized Rate                                                                                                                12069 non-null  object
#  89  PPH Risk-Standardized Rate (Lower Limit)                                                                                                  12069 non-null  object
#  90  PPH Risk-Standardized Rate (Upper Limit)                                                                                                  12069 non-null  object
#  91  PPH Performance Categorization                                                                                                            12069 non-null  object
#  92  Footnote for PPH Risk-Standardized Rate                                                                                                   12069 non-null  object
#  93  How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally               12069 non-null  object
#  94  Footnote for how much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally  12069 non-null  object
#  95  No. of episodes to calc how much Medicare spends per episode of care at agency, compared to spending at all agencies (national)           12069 non-null  object
# dtypes: int64(2), object(94)
# memory usage: 8.8+ MB

# %% [markdown]
# **There are two numerical variables and ninety four categorical variables.**

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.5 Check for missing data.

# %%
# Check for missing values
print("Missing values per column:")
print(data.isnull().sum().sort_values(ascending=False))
# Out:
# Missing values per column:
# State                                                                                                                                       0
# CMS Certification Number (CCN)                                                                                                              0
# Provider Name                                                                                                                               0
# Address                                                                                                                                     0
# City/Town                                                                                                                                   0
#                                                                                                                                            ..
# PPH Performance Categorization                                                                                                              0
# Footnote for PPH Risk-Standardized Rate                                                                                                     0
# How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally                 0
# Footnote for how much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally    0
# No. of episodes to calc how much Medicare spends per episode of care at agency, compared to spending at all agencies (national)             0
# Length: 96, dtype: int64

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.6 Summary of Initial EDA: show shape, data types, and basic info.

# %%
# Initial EDA: show shape, data types, and basic info
initial_eda = {
    "Shape": data.shape,
    "Column Names": data.columns.tolist(),
    "Data Types": data.dtypes,
    "Missing Values": data.isnull().sum().sort_values(ascending=False),
    "Sample Data": data.head(3)
}

initial_eda
# Out:
# {'Shape': (12069, 96),
#  'Column Names': ['State',
#   'CMS Certification Number (CCN)',
#   'Provider Name',
#   'Address',
#   'City/Town',
#   'ZIP Code',
#   'Telephone Number',
#   'Type of Ownership',
#   'Offers Nursing Care Services',
#   'Offers Physical Therapy Services',
#   'Offers Occupational Therapy Services',
#   'Offers Speech Pathology Services',
#   'Offers Medical Social Services',
#   'Offers Home Health Aide Services',
#   'Certification Date',
#   'Quality of patient care star rating',
#   'Footnote for quality of patient care star rating',
#   "Numerator for how often the home health team began their patients' care in a timely manner",
#   "Denominator for how often the home health team began their patients' care in a timely manner",
#   "How often the home health team began their patients' care in a timely manner",
#   "Footnote for how often the home health team began their patients' care in a timely manner",
#   'Numerator for how often the home health team determined whether patients received a flu shot for the current flu season',
#   'Denominator for how often the home health team determined whether patients received a flu shot for the current flu season',
#   'How often the home health team determined whether patients received a flu shot for the current flu season',
#   'Footnote for how often the home health team determined whether patients received a flu shot for the current flu season',
#   'Numerator for how often patients got better at walking or moving around',
#   'Denominator for how often patients got better at walking or moving around',
#   'How often patients got better at walking or moving around',
#   'Footnote for how often patients got better at walking or moving around',
#   'Numerator for how often patients got better at getting in and out of bed',
#   'Denominator for how often patients got better at getting in and out of bed',
#   'How often patients got better at getting in and out of bed',
#   'Footnote for how often patients got better at getting in and out of bed',
#   'Numerator for how often patients got better at bathing',
#   'Denominator for how often patients got better at bathing',
#   'How often patients got better at bathing',
#   'Footnote for how often patients got better at bathing',
#   "Numerator for how often patients' breathing improved",
#   "Denominator for how often patients' breathing improved",
#   "How often patients' breathing improved",
#   "Footnote for how often patients' breathing improved",
#   'Numerator for how often patients got better at taking their drugs correctly by mouth',
#   'Denominator for how often patients got better at taking their drugs correctly by mouth',
#   'How often patients got better at taking their drugs correctly by mouth',
#   'Footnote for how often patients got better at taking their drugs correctly by mouth',
#   'Numerator for Changes in skin integrity post-acute care: pressure ulcer/injury',
#   'Denominator for Changes in skin integrity post-acute care: pressure ulcer/injury',
#   'Changes in skin integrity post-acute care: pressure ulcer/injury',
#   'Footnote Changes in skin integrity post-acute care: pressure ulcer/injury',
#   'Numerator for how often physician-recommended actions to address medication issues were completely timely',
#   'Denominator for how often physician-recommended actions to address medication issues were completely timely',
#   'How often physician-recommended actions to address medication issues were completely timely',
#   'Footnote for how often physician-recommended actions to address medication issues were completely timely',
#   'Numerator for Percent of Residents Experiencing One or More Falls with Major Injury',
#   'Denominator for Percent of Residents Experiencing One or More Falls with Major Injury',
#   'Percent of Residents Experiencing One or More Falls with Major Injury',
#   'Footnote for Percent of Residents Experiencing One or More Falls with Major Injury',
#   'Numerator for Discharge Function Score',
#   'Denominator for Discharge Function Score',
#   'Discharge Function Score',
#   'Footnote for Discharge Function Score',
#   'Numerator for Transfer of Health Information to the Provider',
#   'Denominator for Transfer of Health Information to the Provider',
#   'Transfer of Health Information to the Provider',
#   'Footnote for Transfer of Health Information to the Provider',
#   'Numerator for Transfer of Health Information to the Patient',
#   'Denominator for Transfer of Health Information to the Patient',
#   'Transfer of Health Information to the Patient',
#   'Footnote for Transfer of Health Information to the Patient',
#   'DTC Numerator',
#   'DTC Denominator',
#   'DTC Observed Rate',
#   'DTC Risk-Standardized Rate',
#   'DTC Risk-Standardized Rate (Lower Limit)',
#   'DTC Risk-Standardized Rate (Upper Limit)',
#   'DTC Performance Categorization',
#   'Footnote for DTC Risk-Standardized Rate',
#   'PPR Numerator',
#   'PPR Denominator',
#   'PPR Observed Rate',
#   'PPR Risk-Standardized Rate',
#   'PPR Risk-Standardized Rate (Lower Limit)',
#   'PPR Risk-Standardized Rate (Upper Limit)',
#   'PPR Performance Categorization',
#   'Footnote for PPR Risk-Standardized Rate',
#   'PPH Numerator',
#   'PPH Denominator',
#   'PPH Observed Rate',
#   'PPH Risk-Standardized Rate',
#   'PPH Risk-Standardized Rate (Lower Limit)',
#   'PPH Risk-Standardized Rate (Upper Limit)',
#   'PPH Performance Categorization',
#   'Footnote for PPH Risk-Standardized Rate',
#   'How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally',
#   'Footnote for how much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally',
#   'No. of episodes to calc how much Medicare spends per episode of care at agency, compared to spending at all agencies (national)'],
#  'Data Types': State                                                                                                                                       object
#  CMS Certification Number (CCN)                                                                                                               int64
#  Provider Name                                                                                                                               object
#  Address                                                                                                                                     object
#  City/Town                                                                                                                                   object
#                                                                                                                                               ...
#  PPH Performance Categorization                                                                                                              object
#  Footnote for PPH Risk-Standardized Rate                                                                                                     object
#  How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally                 object
#  Footnote for how much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally    object
#  No. of episodes to calc how much Medicare spends per episode of care at agency, compared to spending at all agencies (national)             object
#  Length: 96, dtype: object,
#  'Missing Values': State                                                                                                                                       0
#  CMS Certification Number (CCN)                                                                                                              0
#  Provider Name                                                                                                                               0
#  Address                                                                                                                                     0
#  City/Town                                                                                                                                   0
#                                                                                                                                             ..
#  PPH Performance Categorization                                                                                                              0
#  Footnote for PPH Risk-Standardized Rate                                                                                                     0
#  How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally                 0
#  Footnote for how much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally    0
#  No. of episodes to calc how much Medicare spends per episode of care at agency, compared to spending at all agencies (national)             0
#  Length: 96, dtype: int64,
#  'Sample Data':   State  CMS Certification Number (CCN)                    Provider Name  \
#  0    AK                           27001    PROVIDENCE HOME HEALTH ALASKA
#  1    AK                           27002    HOSPICE & HOME CARE OF JUNEAU
#  2    AK                           27006  FAIRBANKS MEMORIAL HOSPITAL HHA
#
#                         Address  City/Town  ZIP Code Telephone Number  \
#  0  4001 DALE STREET, SUITE 101  ANCHORAGE     99508       9075630130
#  1         1803 GLACIER HIGHWAY     JUNEAU     99801       9074633113
#  2              1701 GILLAM WAY  FAIRBANKS     99701       9074585410
#
#    Type of Ownership Offers Nursing Care Services  \
#  0        NON-PROFIT                          Yes
#  1        NON-PROFIT                          Yes
#  2        NON-PROFIT                          Yes
#
#    Offers Physical Therapy Services  ... PPH Denominator PPH Observed Rate  \
#  0                              Yes  ...             455             10.11
#  1                              Yes  ...               -                 -
#  2                              Yes  ...             134              5.97
#
#    PPH Risk-Standardized Rate PPH Risk-Standardized Rate (Lower Limit)  \
#  0                       8.37                                     6.56
#  1                          -                                        -
#  2                       7.43                                     4.41
#
#    PPH Risk-Standardized Rate (Upper Limit) PPH Performance Categorization  \
#  0                                    10.49          Same As National Rate
#  1                                        -                              -
#  2                                    11.42          Same As National Rate
#
#               Footnote for PPH Risk-Standardized Rate  \
#  0                                                  -
#  1  This measure currently does not have data or p...
#  2                                                  -
#
#    How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally  \
#  0                                               0.96
#  1                                               0.71
#  2                                               0.77
#
#    Footnote for how much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally  \
#  0                                                  -
#  1                                                  -
#  2                                                  -
#
#    No. of episodes to calc how much Medicare spends per episode of care at agency, compared to spending at all agencies (national)
#  0                                              1,345
#  1                                                151
#  2                                                439
#
#  [3 rows x 96 columns]}

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.7em;color:#00b3e5;">Key Features to Use
# ### Use a subset of the dataset representing cost, quality, and care outcomes:

# %% [markdown]
# | Feature                               | Type                                        | Purpose                               |
# | ------------------------------------- | ------------------------------------------- | ------------------------------------- |
# | `How much Medicare spends...`         | Numeric                                     | Proxy for **cost**                    |
# | `Quality of patient care star rating` | Numeric                                     | Proxy for **quality**                 |
# | `PPH Risk-Standardized Rate`          | Numeric                                     | Proxy for **avoidable hospital use**  |
# | `DTC Risk-Standardized Rate`          | Numeric                                     | Care transition outcomes              |
# | `PPR Risk-Standardized Rate`          | Numeric                                     | Readmission rates                     |
# | `Ownership Type`                      | Categorical → One-hot                       | For subgroup analysis post-clustering |
# | `State`                               | Categorical                                 | For region-based visual analysis      |
# | `No. of episodes to calc...`          | Numeric                                     | Episode Count                         |
# | `Provider Name`                       | Categorical                                 | Name of Provider                      |

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.7em;color:#00b3e5;">Feature Selection and Data Cleaning

# %%
# ---- Step 1: Initial Cleanup ----
# Remove footnote columns, raw numerators/denominators, addresses, and contact details
columns_to_drop = [col for col in data.columns if any(keyword in col for keyword in [
    'Footnote', 'Numerator', 'Denominator', 'Address', 'Telephone', 'ZIP', 'City/Town',
    'Transfer of Health Information', 'Certification Date', 'Offers', 'CMS Certification'
])]

data.drop(columns=columns_to_drop, inplace=True, errors='ignore')

# ---- Step 2: Rename columns for clarity ----
data.rename(columns={
    'Provider Name': 'Provider',
    'Type of Ownership': 'Ownership',
    'Quality of patient care star rating': 'Quality_Star',
    'DTC Risk-Standardized Rate': 'DTC_Rate',
    'PPR Risk-Standardized Rate': 'PPR_Rate',
    'PPH Risk-Standardized Rate': 'PPH_Rate',
    'How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally': 'Medicare_Cost_Ratio',
    'No. of episodes to calc how much Medicare spends per episode of care at agency, compared to spending at all agencies (national)': 'Episode_Count'
}, inplace=True)

# ---- Step 3: Clean numeric columns ----
numeric_cols = ['Quality_Star', 'DTC_Rate', 'PPR_Rate', 'PPH_Rate', 'Medicare_Cost_Ratio', 'Episode_Count']
for col in numeric_cols:
    data[col] = data[col].astype(str).str.replace(',', '').replace('-', pd.NA)
    data[col] = pd.to_numeric(data[col], errors='coerce')

# ---- Step 4: Drop rows with critical missing values ----
data.dropna(subset=numeric_cols, inplace=True)

# ---- Step 5: Summary of cleaned dataset ----
print("Cleaned DataFrame Shape:", data.shape)
print("Remaining Columns:", data.columns.tolist())
print("\nMissing Values Summary:\n", data.isnull().sum())
data.head()
# Out:
# Cleaned DataFrame Shape: (5797, 32)
# Remaining Columns: ['State', 'Provider', 'Ownership', 'Quality_Star', "How often the home health team began their patients' care in a timely manner", 'How often the home health team determined whether patients received a flu shot for the current flu season', 'How often patients got better at walking or moving around', 'How often patients got better at getting in and out of bed', 'How often patients got better at bathing', "How often patients' breathing improved", 'How often patients got better at taking their drugs correctly by mouth', 'Changes in skin integrity post-acute care: pressure ulcer/injury', 'How often physician-recommended actions to address medication issues were completely timely', 'Percent of Residents Experiencing One or More Falls with Major Injury', 'Discharge Function Score', 'DTC Observed Rate', 'DTC_Rate', 'DTC Risk-Standardized Rate (Lower Limit)', 'DTC Risk-Standardized Rate (Upper Limit)', 'DTC Performance Categorization', 'PPR Observed Rate', 'PPR_Rate', 'PPR Risk-Standardized Rate (Lower Limit)', 'PPR Risk-Standardized Rate (Upper Limit)', 'PPR Performance Categorization', 'PPH Observed Rate', 'PPH_Rate', 'PPH Risk-Standardized Rate (Lower Limit)', 'PPH Risk-Standardized Rate (Upper Limit)', 'PPH Performance Categorization', 'Medicare_Cost_Ratio', 'Episode_Count']
#
# Missing Values Summary:
#  State                                                                                                        0
# Provider                                                                                                     0
# Ownership                                                                                                    0
# Quality_Star                                                                                                 0
# How often the home health team began their patients' care in a timely manner                                 0
# How often the home health team determined whether patients received a flu shot for the current flu season    0
# How often patients got better at walking or moving around                                                    0
# How often patients got better at getting in and out of bed                                                   0
# How often patients got better at bathing                                                                     0
# How often patients' breathing improved                                                                       0
# How often patients got better at taking their drugs correctly by mouth                                       0
# Changes in skin integrity post-acute care: pressure ulcer/injury                                             0
# How often physician-recommended actions to address medication issues were completely timely                  0
# Percent of Residents Experiencing One or More Falls with Major Injury                                        0
# Discharge Function Score                                                                                     0
# DTC Observed Rate                                                                                            0
# DTC_Rate                                                                                                     0
# DTC Risk-Standardized Rate (Lower Limit)                                                                     0
# DTC Risk-Standardized Rate (Upper Limit)                                                                     0
# DTC Performance Categorization                                                                               0
# PPR Observed Rate                                                                                            0
# PPR_Rate                                                                                                     0
# PPR Risk-Standardized Rate (Lower Limit)                                                                     0
# PPR Risk-Standardized Rate (Upper Limit)                                                                     0
# PPR Performance Categorization                                                                               0
# PPH Observed Rate                                                                                            0
# PPH_Rate                                                                                                     0
# PPH Risk-Standardized Rate (Lower Limit)                                                                     0
# PPH Risk-Standardized Rate (Upper Limit)                                                                     0
# PPH Performance Categorization                                                                               0
# Medicare_Cost_Ratio                                                                                          0
# Episode_Count                                                                                                0
# dtype: int64
#   State                         Provider            Ownership  Quality_Star  \
# 0    AK    PROVIDENCE HOME HEALTH ALASKA           NON-PROFIT           4.5
# 2    AK  FAIRBANKS MEMORIAL HOSPITAL HHA           NON-PROFIT           2.5
# 3    AK     ANCORA HOME HEALTH & HOSPICE          PROPRIETARY           4.0
# 4    AK   PETERSBURG MEDICAL CENTER HOME  GOVERNMENT OPERATED           1.5
# 5    AK     SOUTH PENINSULA HOSPITAL HHA  GOVERNMENT OPERATED           2.5
#
#   How often the home health team began their patients' care in a timely manner  \
# 0                                               91.3
# 2                                               84.9
# 3                                               69.7
# 4                                               84.7
# 5                                               97.8
#
#   How often the home health team determined whether patients received a flu shot for the current flu season  \
# 0                                               42.3
# 2                                               53.9
# 3                                               48.1
# 4                                               76.9
# 5                                               45.7
#
#   How often patients got better at walking or moving around  \
# 0                                               91.7
# 2                                               74.4
# 3                                               87.0
# 4                                               70.1
# 5                                               72.4
#
#   How often patients got better at getting in and out of bed  \
# 0                                               94.5
# 2                                               84.7
# 3                                               92.7
# 4                                               75.2
# 5                                               84.9
#
#   How often patients got better at bathing  \
# 0                                     96.2
# 2                                     82.6
# 3                                     93.2
# 4                                     64.7
# 5                                     78.8
#
#   How often patients' breathing improved  ...  \
# 0                                  100.0  ...
# 2                                   89.5  ...
# 3                                   93.4  ...
# 4                                   72.8  ...
# 5                                   72.5  ...
#
#   PPR Risk-Standardized Rate (Lower Limit)  \
# 0                                     3.11
# 2                                     2.61
# 3                                     3.56
# 4                                     2.62
# 5                                     2.50
#
#   PPR Risk-Standardized Rate (Upper Limit) PPR Performance Categorization  \
# 0                                     5.09          Same As National Rate
# 2                                     5.05          Same As National Rate
# 3                                     5.25          Same As National Rate
# 4                                     5.86          Same As National Rate
# 5                                     5.31          Same As National Rate
#
#   PPH Observed Rate PPH_Rate PPH Risk-Standardized Rate (Lower Limit)  \
# 0             10.11     8.37                                     6.56
# 2              5.97     7.43                                     4.41
# 3              6.32     6.85                                     5.42
# 4              8.06    11.06                                     6.71
# 5              7.20     8.82                                     5.71
#
#    PPH Risk-Standardized Rate (Upper Limit) PPH Performance Categorization  \
# 0                                     10.49          Same As National Rate
# 2                                     11.42          Same As National Rate
# 3                                      8.59      Better Than National Rate
# 4                                     18.52          Same As National Rate
# 5                                     13.64          Same As National Rate
#
#   Medicare_Cost_Ratio Episode_Count
# 0                0.96        1345.0
# 2                0.77         439.0
# 3                0.85        2406.0
# 4                1.09         232.0
# 5                1.23         335.0
#
# [5 rows x 32 columns]

# %% [markdown]
# **There are now 5797 Observations / Rows and 32 Attributes / Columns and there are no missing values.**

# %% [markdown]
# **Note** All rows with missing values were deleted.
# The columns we’re using for modeling (e.g., Quality_Star, PPH_Rate, DTC_Rate, PPR_Rate, Medicare_Cost_Ratio, Episode_Count) are core numerical features.
# Missing values in these columns means that either the agency didn’t report a key metric or CMS didn’t have enough data to calculate it.
# Including incomplete rows in unsupervised models like KMeans can distort results because clustering requires distance calculations (e.g., Euclidean), which can’t be computed if values are missing. Imputing the missing values incorrectly may introduce bias or false similarity.

# %% [markdown]
# # We will stop here since we already know that the project is to create an unsupervised model.
